# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.style.use('ggplot')
ax=plt.axes()
ax.set(title='Seaborn Example_1',xlabel='X Axsis',ylabel='Y Axsis')
data1 =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
data2=pd.DataFrame(data1,columns=['X Label','Y Label'])
print(data2)
print('='*80)
sns.kdeplot(data2)
# Out:
#        X Label   Y Label
# 0    -1.271291  0.004277
# 1     0.021483 -0.856535
# 2    -0.604019 -0.755438
# 3     2.519900  1.013726
# 4    -3.240654  0.481386
# ...        ...       ...
# 1995  1.240747 -0.262640
# 1996  0.803510 -0.135724
# 1997  4.954296  2.508028
# 1998 -0.229910  0.299313
# 1999  0.501225 -0.187338
#
# [2000 rows x 2 columns]
# ================================================================================
# <AxesSubplot:title={'center':'Seaborn Example_1'}, xlabel='X Axsis', ylabel='Y Axsis'>
